# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("maxhorowitz/nflplaybyplay2009to2016")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'nflplaybyplay2009to2016' dataset.
# Path to dataset files: /kaggle/input/nflplaybyplay2009to2016

# %%
import pandas as pd

# Import dataframe
df = pd.read_csv(path + "/NFL Play by Play 2009-2017 (v4).csv")
df.head(10)
# Out:
# /tmp/ipython-input-4024366084.py:4: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path + "/NFL Play by Play 2009-2017 (v4).csv")
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# 5  2009-09-10  2009091000      2    1   1.0  13:16         14    3496.0
# 6  2009-09-10  2009091000      2    1   2.0  12:40         13    3460.0
# 7  2009-09-10  2009091000      2    1   3.0  12:11         13    3431.0
# 8  2009-09-10  2009091000      2    1   4.0  11:34         12    3394.0
# 9  2009-09-10  2009091000      3    1   1.0  11:24         12    3384.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
# 5          11.0         TEN  ...       NaN     0.558929     0.441071
# 6          36.0         TEN  ...  0.163935     0.578453     0.421547
# 7          29.0         TEN  ...       NaN     0.582881     0.417119
# 8          37.0         TEN  ...       NaN     0.617544     0.382456
# 9          10.0         TEN  ...  0.541602     0.591489     0.408511
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.546433      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.551088      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.510793      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.461217      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.558929      0.441071  0.461217  0.097712       NaN       NaN    2009
# 5      0.578453      0.421547  0.441071 -0.019524       NaN       NaN    2009
# 6      0.582881      0.417119  0.421547 -0.004427 -0.010456  0.006029    2009
# 7      0.617544      0.382456  0.417119 -0.034663       NaN       NaN    2009
# 8      0.591489      0.408511  0.382456  0.026054       NaN       NaN    2009
# 9      0.585405      0.414595  0.591489 -0.006084 -0.024526  0.018442    2009
#
# [10 rows x 102 columns]

# %%
# Print list of columns and number of columns in dataframe for cleaning
columns = list(df.columns)
print(columns)
print(f"Number of columns in dataframe: {len(columns)}")
# Out:
# ['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder', 'TimeSecs', 'PlayTimeDiff', 'SideofField', 'yrdln', 'yrdline100', 'ydstogo', 'ydsnet', 'GoalToGo', 'FirstDown', 'posteam', 'DefensiveTeam', 'desc', 'PlayAttempted', 'Yards.Gained', 'sp', 'Touchdown', 'ExPointResult', 'TwoPointConv', 'DefTwoPoint', 'Safety', 'Onsidekick', 'PuntResult', 'PlayType', 'Passer', 'Passer_ID', 'PassAttempt', 'PassOutcome', 'PassLength', 'AirYards', 'YardsAfterCatch', 'QBHit', 'PassLocation', 'InterceptionThrown', 'Interceptor', 'Rusher', 'Rusher_ID', 'RushAttempt', 'RunLocation', 'RunGap', 'Receiver', 'Receiver_ID', 'Reception', 'ReturnResult', 'Returner', 'BlockingPlayer', 'Tackler1', 'Tackler2', 'FieldGoalResult', 'FieldGoalDistance', 'Fumble', 'RecFumbTeam', 'RecFumbPlayer', 'Sack', 'Challenge.Replay', 'ChalReplayResult', 'Accepted.Penalty', 'PenalizedTeam', 'PenaltyType', 'PenalizedPlayer', 'Penalty.Yards', 'PosTeamScore', 'DefTeamScore', 'ScoreDiff', 'AbsScoreDiff', 'HomeTeam', 'AwayTeam', 'Timeout_Indicator', 'Timeout_Team', 'posteam_timeouts_pre', 'HomeTimeouts_Remaining_Pre', 'AwayTimeouts_Remaining_Pre', 'HomeTimeouts_Remaining_Post', 'AwayTimeouts_Remaining_Post', 'No_Score_Prob', 'Opp_Field_Goal_Prob', 'Opp_Safety_Prob', 'Opp_Touchdown_Prob', 'Field_Goal_Prob', 'Safety_Prob', 'Touchdown_Prob', 'ExPoint_Prob', 'TwoPoint_Prob', 'ExpPts', 'EPA', 'airEPA', 'yacEPA', 'Home_WP_pre', 'Away_WP_pre', 'Home_WP_post', 'Away_WP_post', 'Win_Prob', 'WPA', 'airWPA', 'yacWPA', 'Season']
# Number of columns in dataframe: 102

# %%
# Drop columns from dataframe that contain information from the current play
cols_to_drop = ["Date", "time", "SideofField", "ydsnet", "FirstDown", "DefTwoPoint", "Passer", "Passer_ID", "ExpPts", "WPA", "No_Score_Prob", "Opp_Field_Goal_Prob", "Opp_Safety_Prob", "Opp_Touchdown_Prob", "Field_Goal_Prob", "Safety_Prob", "Touchdown_Prob", "ExPoint_Prob", "TwoPoint_Prob", "airEPA", "yacEPA", "Home_WP_pre", "Away_WP_pre", "Home_WP_post", "Away_WP_post", "Win_Prob", "airWPA", "yacWPA", "desc", "Yards.Gained", "Touchdown", "Safety", "Onsidekick", "PuntResult", "PlayType", "PassLength", "PassAttempt", "PassOutcome", "AirYards", "YardsAfterCatch", "QBHit", "PassLocation", "InterceptionThrown", "Interceptor", "Rusher", "Rusher_ID", "RushAttempt", "RunLocation", "RunGap", "Receiver", "Receiver_ID", "Reception", "ReturnResult", "Returner", "BlockingPlayer", "Tackler1", "Tackler2", "FieldGoalResult", "FieldGoalDistance", "Fumble", "RecFumbTeam", "RecFumbPlayer", "Sack", "Challenge.Replay", "ChalReplayResult", "Accepted.Penalty", "PenalizedTeam", "PenaltyType", "PenalizedPlayer", "Penalty.Yards", "PosTeamScore", "DefTeamScore", "ExPointResult", "TwoPointConv", "sp"]
df_clean = df.drop(columns=cols_to_drop, axis=1)

columns = list(df_clean.columns)
print(columns)
print(f"Number of columns in dataframe: {len(columns)}")
# Out:
# ['GameID', 'Drive', 'qtr', 'down', 'TimeUnder', 'TimeSecs', 'PlayTimeDiff', 'yrdln', 'yrdline100', 'ydstogo', 'GoalToGo', 'posteam', 'DefensiveTeam', 'PlayAttempted', 'ScoreDiff', 'AbsScoreDiff', 'HomeTeam', 'AwayTeam', 'Timeout_Indicator', 'Timeout_Team', 'posteam_timeouts_pre', 'HomeTimeouts_Remaining_Pre', 'AwayTimeouts_Remaining_Pre', 'HomeTimeouts_Remaining_Post', 'AwayTimeouts_Remaining_Post', 'EPA', 'Season']
# Number of columns in dataframe: 27

# %%
pd.set_option('display.max_columns', None)
df_clean.head()
# Out:
#        GameID  Drive  qtr  down  TimeUnder  TimeSecs  PlayTimeDiff  yrdln  \
# 0  2009091000      1    1   NaN         15    3600.0           0.0   30.0
# 1  2009091000      1    1   1.0         15    3593.0           7.0   42.0
# 2  2009091000      1    1   2.0         15    3556.0          37.0   47.0
# 3  2009091000      1    1   3.0         14    3515.0          41.0   44.0
# 4  2009091000      1    1   4.0         14    3507.0           8.0   44.0
#
#    yrdline100  ydstogo  GoalToGo posteam DefensiveTeam  PlayAttempted  \
# 0        30.0        0       0.0     PIT           TEN              1
# 1        58.0       10       0.0     PIT           TEN              1
# 2        53.0        5       0.0     PIT           TEN              1
# 3        56.0        8       0.0     PIT           TEN              1
# 4        56.0        8       0.0     PIT           TEN              1
#
#    ScoreDiff  AbsScoreDiff HomeTeam AwayTeam  Timeout_Indicator Timeout_Team  \
# 0        0.0           0.0      PIT      TEN                  0          NaN
# 1        0.0           0.0      PIT      TEN                  0          NaN
# 2        0.0           0.0      PIT      TEN                  0          NaN
# 3        0.0           0.0      PIT      TEN                  0          NaN
# 4        0.0           0.0      PIT      TEN                  0          NaN
#
#    posteam_timeouts_pre  HomeTimeouts_Remaining_Pre  \
# 0                     3                           3
# 1                     3                           3
# 2                     3                           3
# 3                     3                           3
# 4                     3                           3
#
#    AwayTimeouts_Remaining_Pre  HomeTimeouts_Remaining_Post  \
# 0                           3                            3
# 1                           3                            3
# 2                           3                            3
# 3                           3                            3
# 4                           3                            3
#
#    AwayTimeouts_Remaining_Post       EPA  Season
# 0                            3  2.014474    2009
# 1                            3  0.077907    2009
# 2                            3 -1.402760    2009
# 3                            3 -1.712583    2009
# 4                            3  2.097796    2009

# %%
# Remove all NaNs that are associated with end of quarter/half/game/etc.
df_clean = df_clean[df_clean['down'].notna()]
df_clean = df_clean[df_clean['PlayTimeDiff'].notna()]
df_clean = df_clean[df_clean['EPA'].notna()]

# Clean string identifiers from dataframe and create integer identifiers
# Attribute timeouts to 'posteam' or 'DefensiveTeam' instead of team name
df_clean['timeout_by_offense'] = (df_clean['Timeout_Team'] == df_clean['posteam']).astype(int)
df_clean['timeout_by_defense'] = (df_clean['Timeout_Team'] == df_clean['DefensiveTeam']).astype(int)
# Link possession team and defensive team to home or away team
df_clean["offense_is_home"] = (df_clean["posteam"] == df_clean["HomeTeam"]).astype(int)
df_clean["defense_is_home"] = (df_clean["DefensiveTeam"] == df_clean["HomeTeam"]).astype(int)
# Feature for model to attribute to different teams within the league
df_clean = pd.get_dummies(df_clean, columns = ["HomeTeam", "AwayTeam"], prefix=["home", "away"])
# Drop columns with string identifiers
df_clean = df_clean.drop(columns=['Timeout_Team', 'posteam', 'DefensiveTeam'])

# Print dataframe features to screen
df_clean.head()
# Out:
#        GameID  Drive  qtr  down  TimeUnder  TimeSecs  PlayTimeDiff  yrdln  \
# 1  2009091000      1    1   1.0         15    3593.0           7.0   42.0
# 2  2009091000      1    1   2.0         15    3556.0          37.0   47.0
# 3  2009091000      1    1   3.0         14    3515.0          41.0   44.0
# 4  2009091000      1    1   4.0         14    3507.0           8.0   44.0
# 5  2009091000      2    1   1.0         14    3496.0          11.0    2.0
#
#    yrdline100  ydstogo  GoalToGo  PlayAttempted  ScoreDiff  AbsScoreDiff  \
# 1        58.0       10       0.0              1        0.0           0.0
# 2        53.0        5       0.0              1        0.0           0.0
# 3        56.0        8       0.0              1        0.0           0.0
# 4        56.0        8       0.0              1        0.0           0.0
# 5        98.0       10       0.0              1        0.0           0.0
#
#    Timeout_Indicator  posteam_timeouts_pre  HomeTimeouts_Remaining_Pre  \
# 1                  0                     3                           3
# 2                  0                     3                           3
# 3                  0                     3                           3
# 4                  0                     3                           3
# 5                  0                     3                           3
#
#    AwayTimeouts_Remaining_Pre  HomeTimeouts_Remaining_Post  \
# 1                           3                            3
# 2                           3                            3
# 3                           3                            3
# 4                           3                            3
# 5                           3                            3
#
#    AwayTimeouts_Remaining_Post       EPA  Season  timeout_by_offense  \
# 1                            3  0.077907    2009                   0
# 2                            3 -1.402760    2009                   0
# 3                            3 -1.712583    2009                   0
# 4                            3  2.097796    2009                   0
# 5                            3 -0.696302    2009                   0
#
#    timeout_by_defense  offense_is_home  defense_is_home  home_ARI  home_ATL  \
# 1                   0                1                0     False     False
# 2                   0                1                0     False     False
# 3                   0                1                0     False     False
# 4                   0                1                0     False     False
# 5                   0                0                1     False     False
#
#    home_BAL  home_BUF  home_CAR  home_CHI  home_CIN  home_CLE  home_DAL  \
# 1     False     False     False     False     False     False     False
# 2     False     False     False     False     False     False     False
# 3     False     False     False     False     False     False     False
# 4     False     False     False     False     False     False     False
# 5     False     False     False     False     False     False     False
#
#    home_DEN  home_DET  home_GB  home_HOU  home_IND  home_JAC  home_JAX  \
# 1     False     False    False     False     False     False     False
# 2     False     False    False     False     False     False     False
# 3     False     False    False     False     False     False     False
# 4     False     False    False     False     False     False     False
# 5     False     False    False     False     False     False     False
#
#    home_KC  home_LA  home_LAC  home_MIA  home_MIN  home_NE  home_NO  home_NYG  \
# 1    False    False     False     False     False    False    False     False
# 2    False    False     False     False     False    False    False     False
# 3    False    False     False     False     False    False    False     False
# 4    False    False     False     False     False    False    False     False
# 5    False    False     False     False     False    False    False     False
#
#    home_NYJ  home_OAK  home_PHI  home_PIT  home_SD  home_SEA  home_SF  \
# 1     False     False     False      True    False     False    False
# 2     False     False     False      True    False     False    False
# 3     False     False     False      True    False     False    False
# 4     False     False     False      True    False     False    False
# 5     False     False     False      True    False     False    False
#
#    home_STL  home_TB  home_TEN  home_WAS  away_ARI  away_ATL  away_BAL  \
# 1     False    False     False     False     False     False     False
# 2     False    False     False     False     False     False     False
# 3     False    False     False     False     False     False     False
# 4     False    False     False     False     False     False     False
# 5     False    False     False     False     False     False     False
#
#    away_BUF  away_CAR  away_CHI  away_CIN  away_CLE  away_DAL  away_DEN  \
# 1     False     False     False     False     False     False     False
# 2     False     False     False     False     False     False     False
# 3     False     False     False     False     False     False     False
# 4     False     False     False     False     False     False     False
# 5     False     False     False     False     False     False     False
#
#    away_DET  away_GB  away_HOU  away_IND  away_JAC  away_JAX  away_KC  \
# 1     False    False     False     False     False     False    False
# 2     False    False     False     False     False     False    False
# 3     False    False     False     False     False     False    False
# 4     False    False     False     False     False     False    False
# 5     False    False     False     False     False     False    False
#
#    away_LA  away_LAC  away_MIA  away_MIN  away_NE  away_NO  away_NYG  \
# 1    False     False     False     False    False    False     False
# 2    False     False     False     False    False    False     False
# 3    False     False     False     False    False    False     False
# 4    False     False     False     False    False    False     False
# 5    False     False     False     False    False    False     False
#
#    away_NYJ  away_OAK  away_PHI  away_PIT  away_SD  away_SEA  away_SF  \
# 1     False     False     False     False    False     False    False
# 2     False     False     False     False    False     False    False
# 3     False     False     False     False    False     False    False
# 4     False     False     False     False    False     False    False
# 5     False     False     False     False    False     False    False
#
#    away_STL  away_TB  away_TEN  away_WAS
# 1     False    False      True     False
# 2     False    False      True     False
# 3     False    False      True     False
# 4     False    False      True     False
# 5     False    False      True     False

# %%
# Ensure all NaNs have been removed from dataframe
df_clean.isna().sum()
# Out:
# GameID       0
# Drive        0
# qtr          0
# down         0
# TimeUnder    0
#             ..
# away_SF      0
# away_STL     0
# away_TB      0
# away_TEN     0
# away_WAS     0
# Length: 96, dtype: int64

# %%
# Print number of dataframe points
print(f"Number of rows in dataframe: {len(df_clean)}")
# Out:
# Number of rows in dataframe: 346339

# %%
from sklearn.model_selection import train_test_split

# Identify total number of games contained within dataframe
game_ids = df_clean["GameID"].unique()
print(f"Total number of games played: {len(game_ids)}")

# Split on game_ids
train_ids, test_ids = train_test_split(game_ids, test_size=0.15, random_state=42)
train_ids, val_ids = train_test_split(train_ids, test_size=.1765, random_state=42)

# Validate train, test and val set sizes
print(f"Number of games in train set: {len(train_ids)}")
print(f"Number of games in val set: {len(val_ids)}")
print(f"Number of games in test set: {len(test_ids)}")
# Out:
# Total number of games played: 2304
# Number of games in train set: 1612
# Number of games in val set: 346
# Number of games in test set: 346

# %%
# Ensure no play from a game appears in more than one subset, each subset contains entire games, and validation and test subsets are unseen
train_df = df_clean[df_clean['GameID'].isin(train_ids)]
val_df = df_clean[df_clean['GameID'].isin(val_ids)]
test_df = df_clean[df_clean['GameID'].isin(test_ids)]

# %%
# Define target variable and feature variables
target_col = 'EPA'
feature_cols = [col for col in df_clean.columns if col != target_col]

# %%
# Extract y from datafame for train, val, and test
X_train = train_df[feature_cols]
y_train = train_df[target_col]

X_val = val_df[feature_cols]
y_val = val_df[target_col]

X_test = test_df[feature_cols]
y_test = test_df[target_col]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Normalize training data
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
import keras
from keras import layers
from keras.layers import Flatten
from keras.layers import Dense

def create_model():
  model = keras.Sequential([
      Dense(4, activation='tanh', input_shape=[len(feature_cols)]),
      Dense(6, activation='tanh'),
      Dense(1, activation='linear')
  ])

  model.compile(
      optimizer='adam',
      loss='mse',
      metrics=['mae', 'mse']
      )

  return model

model = create_model()

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 421 (1.64 KB)
#  Trainable params: 421 (1.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import os

checkpoint_path = "training_1/cp.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)
os.makedirs(checkpoint_dir, exist_ok=True)

cp_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    save_best_only=True,
    verbose=1
    )

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=7,
                                           restore_best_weights=True
                                           )

os.listdir(checkpoint_dir)

history = model.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    batch_size=256,
    validation_data=(X_val_scaled, y_val),
    callbacks=[cp_callback, early_stop]
    )
# Out:
# Epoch 1/100
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0734 - mae: 1.0062 - mse: 2.0734
# Epoch 1: val_loss improved from inf to 1.96316, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 2.0733 - mae: 1.0062 - mse: 2.0733 - val_loss: 1.9632 - val_mae: 0.9649 - val_mse: 1.9632
# Epoch 2/100
# 940/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9424 - mae: 0.9596 - mse: 1.9424
# Epoch 2: val_loss improved from 1.96316 to 1.96101, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9425 - mae: 0.9596 - mse: 1.9425 - val_loss: 1.9610 - val_mae: 0.9661 - val_mse: 1.9610
# Epoch 3/100
# 926/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9539 - mae: 0.9621 - mse: 1.9539
# Epoch 3: val_loss did not improve from 1.96101
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9539 - mae: 0.9621 - mse: 1.9539 - val_loss: 1.9614 - val_mae: 0.9629 - val_mse: 1.9614
# Epoch 4/100
# 945/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9768 - mae: 0.9651 - mse: 1.9768
# Epoch 4: val_loss did not improve from 1.96101
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9767 - mae: 0.9651 - mse: 1.9767 - val_loss: 1.9618 - val_mae: 0.9673 - val_mse: 1.9618
# Epoch 5/100
# 927/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9647 - mae: 0.9640 - mse: 1.9647
# Epoch 5: val_loss did not improve from 1.96101
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9645 - mae: 0.9639 - mse: 1.9645 - val_loss: 1.9610 - val_mae: 0.9645 - val_mse: 1.9610
# Epoch 6/100
# 934/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9603 - mae: 0.9629 - mse: 1.9603
# Epoch 6: val_loss improved from 1.96101 to 1.96088, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9602 - mae: 0.9629 - mse: 1.9602 - val_loss: 1.9609 - val_mae: 0.9670 - val_mse: 1.9609
# Epoch 7/100
# 943/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9412 - mae: 0.9594 - mse: 1.9412
# Epoch 7: val_loss improved from 1.96088 to 1.95940, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9413 - mae: 0.9594 - mse: 1.9413 - val_loss: 1.9594 - val_mae: 0.9648 - val_mse: 1.9594
# Epoch 8/100
# 943/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9375 - mae: 0.9581 - mse: 1.9375
# Epoch 8: val_loss did not improve from 1.95940
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9376 - mae: 0.9581 - mse: 1.9376 - val_loss: 1.9606 - val_mae: 0.9685 - val_mse: 1.9606
# Epoch 9/100
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9447 - mae: 0.9605 - mse: 1.9447
# Epoch 9: val_loss did not improve from 1.95940
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9447 - mae: 0.9605 - mse: 1.9447 - val_loss: 1.9603 - val_mae: 0.9653 - val_mse: 1.9603
# Epoch 10/100
# 939/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9566 - mae: 0.9628 - mse: 1.9566
# Epoch 10: val_loss did not improve from 1.95940
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9566 - mae: 0.9628 - mse: 1.9566 - val_loss: 1.9606 - val_mae: 0.9667 - val_mse: 1.9606
# Epoch 11/100
# 940/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9490 - mae: 0.9622 - mse: 1.9490
# Epoch 11: val_loss did not improve from 1.95940
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9490 - mae: 0.9622 - mse: 1.9490 - val_loss: 1.9598 - val_mae: 0.9662 - val_mse: 1.9598
# Epoch 12/100
# 933/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9589 - mae: 0.9631 - mse: 1.9589
# Epoch 12: val_loss did not improve from 1.95940
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.9588 - mae: 0.9631 - mse: 1.9588 - val_loss: 1.9611 - val_mae: 0.9677 - val_mse: 1.9611
# Epoch 13/100
# 928/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9490 - mae: 0.9606 - mse: 1.9490
# Epoch 13: val_loss did not improve from 1.95940
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9490 - mae: 0.9606 - mse: 1.9490 - val_loss: 1.9604 - val_mae: 0.9686 - val_mse: 1.9604
# Epoch 14/100
# 930/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9359 - mae: 0.9576 - mse: 1.9359
# Epoch 14: val_loss improved from 1.95940 to 1.95901, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9361 - mae: 0.9576 - mse: 1.9361 - val_loss: 1.9590 - val_mae: 0.9667 - val_mse: 1.9590
# Epoch 15/100
# 943/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9454 - mae: 0.9618 - mse: 1.9454
# Epoch 15: val_loss did not improve from 1.95901
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9455 - mae: 0.9618 - mse: 1.9455 - val_loss: 1.9601 - val_mae: 0.9685 - val_mse: 1.9601
# Epoch 16/100
# 931/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9379 - mae: 0.9584 - mse: 1.9379
# Epoch 16: val_loss did not improve from 1.95901
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 1.9381 - mae: 0.9585 - mse: 1.9381 - val_loss: 1.9599 - val_mae: 0.9670 - val_mse: 1.9599
# Epoch 17/100
# 946/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9538 - mae: 0.9624 - mse: 1.9538
# Epoch 17: val_loss did not improve from 1.95901
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9537 - mae: 0.9624 - mse: 1.9537 - val_loss: 1.9597 - val_mae: 0.9659 - val_mse: 1.9597
# Epoch 18/100
# 946/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9473 - mae: 0.9605 - mse: 1.9473
# Epoch 18: val_loss did not improve from 1.95901
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9473 - mae: 0.9605 - mse: 1.9473 - val_loss: 1.9598 - val_mae: 0.9640 - val_mse: 1.9598
# Epoch 19/100
# 928/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9447 - mae: 0.9617 - mse: 1.9447
# Epoch 19: val_loss did not improve from 1.95901
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9447 - mae: 0.9617 - mse: 1.9447 - val_loss: 1.9591 - val_mae: 0.9657 - val_mse: 1.9591
# Epoch 20/100
# 939/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9432 - mae: 0.9600 - mse: 1.9432
# Epoch 20: val_loss improved from 1.95901 to 1.95894, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9433 - mae: 0.9601 - mse: 1.9433 - val_loss: 1.9589 - val_mae: 0.9662 - val_mse: 1.9589
# Epoch 21/100
# 933/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9396 - mae: 0.9588 - mse: 1.9396
# Epoch 21: val_loss did not improve from 1.95894
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9397 - mae: 0.9589 - mse: 1.9397 - val_loss: 1.9591 - val_mae: 0.9653 - val_mse: 1.9591
# Epoch 22/100
# 937/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9515 - mae: 0.9621 - mse: 1.9515
# Epoch 22: val_loss did not improve from 1.95894
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9515 - mae: 0.9620 - mse: 1.9515 - val_loss: 1.9600 - val_mae: 0.9676 - val_mse: 1.9600
# Epoch 23/100
# 936/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9477 - mae: 0.9594 - mse: 1.9477
# Epoch 23: val_loss improved from 1.95894 to 1.95886, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9477 - mae: 0.9594 - mse: 1.9477 - val_loss: 1.9589 - val_mae: 0.9653 - val_mse: 1.9589
# Epoch 24/100
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9340 - mae: 0.9568 - mse: 1.9340
# Epoch 24: val_loss did not improve from 1.95886
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9340 - mae: 0.9568 - mse: 1.9340 - val_loss: 1.9595 - val_mae: 0.9659 - val_mse: 1.9595
# Epoch 25/100
# 928/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9549 - mae: 0.9628 - mse: 1.9549
# Epoch 25: val_loss did not improve from 1.95886
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9547 - mae: 0.9628 - mse: 1.9547 - val_loss: 1.9600 - val_mae: 0.9643 - val_mse: 1.9600
# Epoch 26/100
# 926/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9650 - mae: 0.9639 - mse: 1.9650
# Epoch 26: val_loss did not improve from 1.95886
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9646 - mae: 0.9638 - mse: 1.9646 - val_loss: 1.9594 - val_mae: 0.9658 - val_mse: 1.9594
# Epoch 27/100
# 946/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9440 - mae: 0.9598 - mse: 1.9440
# Epoch 27: val_loss did not improve from 1.95886
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9440 - mae: 0.9598 - mse: 1.9440 - val_loss: 1.9589 - val_mae: 0.9668 - val_mse: 1.9589
# Epoch 28/100
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9182 - mae: 0.9543 - mse: 1.9182
# Epoch 28: val_loss did not improve from 1.95886
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9183 - mae: 0.9543 - mse: 1.9183 - val_loss: 1.9599 - val_mae: 0.9674 - val_mse: 1.9599
# Epoch 29/100
# 930/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9280 - mae: 0.9563 - mse: 1.9280
# Epoch 29: val_loss improved from 1.95886 to 1.95873, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9283 - mae: 0.9564 - mse: 1.9283 - val_loss: 1.9587 - val_mae: 0.9658 - val_mse: 1.9587
# Epoch 30/100
# 931/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9289 - mae: 0.9565 - mse: 1.9289
# Epoch 30: val_loss improved from 1.95873 to 1.95865, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9292 - mae: 0.9566 - mse: 1.9292 - val_loss: 1.9586 - val_mae: 0.9667 - val_mse: 1.9586
# Epoch 31/100
# 932/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9300 - mae: 0.9580 - mse: 1.9300
# Epoch 31: val_loss did not improve from 1.95865
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9303 - mae: 0.9581 - mse: 1.9303 - val_loss: 1.9588 - val_mae: 0.9657 - val_mse: 1.9588
# Epoch 32/100
# 926/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9474 - mae: 0.9598 - mse: 1.9474
# Epoch 32: val_loss did not improve from 1.95865
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.9474 - mae: 0.9598 - mse: 1.9474 - val_loss: 1.9602 - val_mae: 0.9692 - val_mse: 1.9602
# Epoch 33/100
# 927/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9339 - mae: 0.9580 - mse: 1.9339
# Epoch 33: val_loss did not improve from 1.95865
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9341 - mae: 0.9581 - mse: 1.9341 - val_loss: 1.9591 - val_mae: 0.9650 - val_mse: 1.9591
# Epoch 34/100
# 938/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9617 - mae: 0.9627 - mse: 1.9617
# Epoch 34: val_loss improved from 1.95865 to 1.95805, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9615 - mae: 0.9627 - mse: 1.9615 - val_loss: 1.9581 - val_mae: 0.9671 - val_mse: 1.9581
# Epoch 35/100
# 938/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9438 - mae: 0.9590 - mse: 1.9438
# Epoch 35: val_loss improved from 1.95805 to 1.95723, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9439 - mae: 0.9590 - mse: 1.9439 - val_loss: 1.9572 - val_mae: 0.9665 - val_mse: 1.9572
# Epoch 36/100
# 944/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9321 - mae: 0.9559 - mse: 1.9321
# Epoch 36: val_loss did not improve from 1.95723
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9322 - mae: 0.9560 - mse: 1.9322 - val_loss: 1.9587 - val_mae: 0.9651 - val_mse: 1.9587
# Epoch 37/100
# 929/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9291 - mae: 0.9569 - mse: 1.9291
# Epoch 37: val_loss did not improve from 1.95723
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9294 - mae: 0.9569 - mse: 1.9294 - val_loss: 1.9585 - val_mae: 0.9642 - val_mse: 1.9585
# Epoch 38/100
# 945/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9584 - mae: 0.9627 - mse: 1.9584
# Epoch 38: val_loss did not improve from 1.95723
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9583 - mae: 0.9627 - mse: 1.9583 - val_loss: 1.9591 - val_mae: 0.9676 - val_mse: 1.9591
# Epoch 39/100
# 930/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9579 - mae: 0.9632 - mse: 1.9579
# Epoch 39: val_loss did not improve from 1.95723
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9577 - mae: 0.9631 - mse: 1.9577 - val_loss: 1.9579 - val_mae: 0.9663 - val_mse: 1.9579
# Epoch 40/100
# 946/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9384 - mae: 0.9573 - mse: 1.9384
# Epoch 40: val_loss did not improve from 1.95723
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9385 - mae: 0.9573 - mse: 1.9385 - val_loss: 1.9576 - val_mae: 0.9656 - val_mse: 1.9576
# Epoch 41/100
# 927/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9613 - mae: 0.9622 - mse: 1.9613
# Epoch 41: val_loss did not improve from 1.95723
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9609 - mae: 0.9622 - mse: 1.9609 - val_loss: 1.9587 - val_mae: 0.9640 - val_mse: 1.9587
# Epoch 42/100
# 943/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9331 - mae: 0.9570 - mse: 1.9331
# Epoch 42: val_loss did not improve from 1.95723
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9332 - mae: 0.9570 - mse: 1.9332 - val_loss: 1.9585 - val_mae: 0.9624 - val_mse: 1.9585

# %%
history_dict = history.history
print(history_dict.keys())
# Out:
# dict_keys(['loss', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse'])

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'r--', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.xticks(epochs)
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import numpy as np

# Pick a random subset of validation data for permutation importance
rng = np.random.default_rng(42)
n_samples = min(10000, X_val_scaled.shape[0])

indices = rng.choice(X_val_scaled.shape[0], size=n_samples, replace=False)

X_val_sub = X_val_scaled[indices]
y_val_sub = y_val.iloc[indices] if hasattr(y_val, "iloc") else y_val[indices]

# %%
# define MAE scoring function for permutation importance
from sklearn.metrics import mean_absolute_error

def mae_scorer(model, X, y):
  y_pred = model.predict(X, batch_size=4096, verbose=0)
  return -mean_absolute_error(y, y_pred)  # negative because higher is better

mae_scorer(model, X_val_scaled, y_val)
# Out:
# -0.9665010620660215

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(
    model,
    X_val_sub,
    y_val_sub,
    scoring=mae_scorer,
    n_repeats=5,
    random_state=42,
    n_jobs=1
    )

importance_df = pd.DataFrame({
    "feature": feature_cols,
    "importance": result.importances_mean
    })

importance_df.sort_values(by="importance", ascending=False, inplace=True)

top_k = 20
plt.figure(figsize=(8,6))
plt.barh(importance_df["feature"].head(top_k)[::-1],
         importance_df["importance"].head(top_k)[::-1])
plt.xlabel("Mean drop in validation score")
plt.title("Permutation feature importance")
# plt.tight_layout()
plt.show()

# %%
results = model.evaluate(X_test_scaled, y_test, batch_size=256)
print("test loss, test acc:", results)
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.9598 - mae: 0.9610 - mse: 1.9598
# test loss, test acc: [1.9439102411270142, 0.9638147950172424, 1.9439102411270142]

# %%
# Obtain EPA predictions per play
y_pred = model.predict(X_test_scaled)
# Out:
# 1622/1622 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %%
# Add predictions back into test dataframe
test_df = test_df.copy()
test_df['EPA_pred'] = y_pred
test_df['EPA_true'] = y_test

# %%
# Aggregate per game
game_results = test_df.groupby("GameID")[["EPA_true", "EPA_pred"]].sum()
# Mean absolute EPA error per game
game_results["game_MAE"] = (game_results["EPA_true"] - game_results["EPA_pred"]).abs()
overall_game_MAE = game_results["game_MAE"].mean()
print(f"Overall game MAE: {overall_game_MAE}")
# Out:
# Overall game MAE: 15.952571891091349
