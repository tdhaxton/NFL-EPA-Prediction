# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("maxhorowitz/nflplaybyplay2009to2016")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'nflplaybyplay2009to2016' dataset.
# Path to dataset files: /kaggle/input/nflplaybyplay2009to2016

# %%
import pandas as pd

# Import dataframe
df = pd.read_csv(path + "/NFL Play by Play 2009-2017 (v4).csv")
df.head(10)
# Out:
# /tmp/ipython-input-4024366084.py:4: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path + "/NFL Play by Play 2009-2017 (v4).csv")
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# 5  2009-09-10  2009091000      2    1   1.0  13:16         14    3496.0
# 6  2009-09-10  2009091000      2    1   2.0  12:40         13    3460.0
# 7  2009-09-10  2009091000      2    1   3.0  12:11         13    3431.0
# 8  2009-09-10  2009091000      2    1   4.0  11:34         12    3394.0
# 9  2009-09-10  2009091000      3    1   1.0  11:24         12    3384.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
# 5          11.0         TEN  ...       NaN     0.558929     0.441071
# 6          36.0         TEN  ...  0.163935     0.578453     0.421547
# 7          29.0         TEN  ...       NaN     0.582881     0.417119
# 8          37.0         TEN  ...       NaN     0.617544     0.382456
# 9          10.0         TEN  ...  0.541602     0.591489     0.408511
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.546433      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.551088      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.510793      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.461217      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.558929      0.441071  0.461217  0.097712       NaN       NaN    2009
# 5      0.578453      0.421547  0.441071 -0.019524       NaN       NaN    2009
# 6      0.582881      0.417119  0.421547 -0.004427 -0.010456  0.006029    2009
# 7      0.617544      0.382456  0.417119 -0.034663       NaN       NaN    2009
# 8      0.591489      0.408511  0.382456  0.026054       NaN       NaN    2009
# 9      0.585405      0.414595  0.591489 -0.006084 -0.024526  0.018442    2009
#
# [10 rows x 102 columns]

# %%
# Print list of columns and number of columns in dataframe for cleaning
columns = list(df.columns)
print(columns)
print(f"Number of columns in dataframe: {len(columns)}")
# Out:
# ['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder', 'TimeSecs', 'PlayTimeDiff', 'SideofField', 'yrdln', 'yrdline100', 'ydstogo', 'ydsnet', 'GoalToGo', 'FirstDown', 'posteam', 'DefensiveTeam', 'desc', 'PlayAttempted', 'Yards.Gained', 'sp', 'Touchdown', 'ExPointResult', 'TwoPointConv', 'DefTwoPoint', 'Safety', 'Onsidekick', 'PuntResult', 'PlayType', 'Passer', 'Passer_ID', 'PassAttempt', 'PassOutcome', 'PassLength', 'AirYards', 'YardsAfterCatch', 'QBHit', 'PassLocation', 'InterceptionThrown', 'Interceptor', 'Rusher', 'Rusher_ID', 'RushAttempt', 'RunLocation', 'RunGap', 'Receiver', 'Receiver_ID', 'Reception', 'ReturnResult', 'Returner', 'BlockingPlayer', 'Tackler1', 'Tackler2', 'FieldGoalResult', 'FieldGoalDistance', 'Fumble', 'RecFumbTeam', 'RecFumbPlayer', 'Sack', 'Challenge.Replay', 'ChalReplayResult', 'Accepted.Penalty', 'PenalizedTeam', 'PenaltyType', 'PenalizedPlayer', 'Penalty.Yards', 'PosTeamScore', 'DefTeamScore', 'ScoreDiff', 'AbsScoreDiff', 'HomeTeam', 'AwayTeam', 'Timeout_Indicator', 'Timeout_Team', 'posteam_timeouts_pre', 'HomeTimeouts_Remaining_Pre', 'AwayTimeouts_Remaining_Pre', 'HomeTimeouts_Remaining_Post', 'AwayTimeouts_Remaining_Post', 'No_Score_Prob', 'Opp_Field_Goal_Prob', 'Opp_Safety_Prob', 'Opp_Touchdown_Prob', 'Field_Goal_Prob', 'Safety_Prob', 'Touchdown_Prob', 'ExPoint_Prob', 'TwoPoint_Prob', 'ExpPts', 'EPA', 'airEPA', 'yacEPA', 'Home_WP_pre', 'Away_WP_pre', 'Home_WP_post', 'Away_WP_post', 'Win_Prob', 'WPA', 'airWPA', 'yacWPA', 'Season']
# Number of columns in dataframe: 102

# %%
# Drop columns from dataframe that contain information from the current play
cols_to_drop = ["Date", "time", "SideofField", "ydsnet", "FirstDown", "DefTwoPoint", "Passer", "Passer_ID", "ExpPts", "WPA", "No_Score_Prob", "Opp_Field_Goal_Prob", "Opp_Safety_Prob", "Opp_Touchdown_Prob", "Field_Goal_Prob", "Safety_Prob", "Touchdown_Prob", "ExPoint_Prob", "TwoPoint_Prob", "airEPA", "yacEPA", "Home_WP_pre", "Away_WP_pre", "Home_WP_post", "Away_WP_post", "Win_Prob", "airWPA", "yacWPA", "desc", "Yards.Gained", "Touchdown", "Safety", "Onsidekick", "PuntResult", "PlayType", "PassLength", "PassAttempt", "PassOutcome", "AirYards", "YardsAfterCatch", "QBHit", "PassLocation", "InterceptionThrown", "Interceptor", "Rusher", "Rusher_ID", "RushAttempt", "RunLocation", "RunGap", "Receiver", "Receiver_ID", "Reception", "ReturnResult", "Returner", "BlockingPlayer", "Tackler1", "Tackler2", "FieldGoalResult", "FieldGoalDistance", "Fumble", "RecFumbTeam", "RecFumbPlayer", "Sack", "Challenge.Replay", "ChalReplayResult", "Accepted.Penalty", "PenalizedTeam", "PenaltyType", "PenalizedPlayer", "Penalty.Yards", "PosTeamScore", "DefTeamScore", "ExPointResult", "TwoPointConv", "sp"]
df_clean = df.drop(columns=cols_to_drop, axis=1)

columns = list(df_clean.columns)
print(columns)
print(f"Number of columns in dataframe: {len(columns)}")
# Out:
# ['GameID', 'Drive', 'qtr', 'down', 'TimeUnder', 'TimeSecs', 'PlayTimeDiff', 'yrdln', 'yrdline100', 'ydstogo', 'GoalToGo', 'posteam', 'DefensiveTeam', 'PlayAttempted', 'ScoreDiff', 'AbsScoreDiff', 'HomeTeam', 'AwayTeam', 'Timeout_Indicator', 'Timeout_Team', 'posteam_timeouts_pre', 'HomeTimeouts_Remaining_Pre', 'AwayTimeouts_Remaining_Pre', 'HomeTimeouts_Remaining_Post', 'AwayTimeouts_Remaining_Post', 'EPA', 'Season']
# Number of columns in dataframe: 27

# %%
pd.set_option('display.max_columns', None)
df_clean.head()
# Out:
#        GameID  Drive  qtr  down  TimeUnder  TimeSecs  PlayTimeDiff  yrdln  \
# 0  2009091000      1    1   NaN         15    3600.0           0.0   30.0
# 1  2009091000      1    1   1.0         15    3593.0           7.0   42.0
# 2  2009091000      1    1   2.0         15    3556.0          37.0   47.0
# 3  2009091000      1    1   3.0         14    3515.0          41.0   44.0
# 4  2009091000      1    1   4.0         14    3507.0           8.0   44.0
#
#    yrdline100  ydstogo  GoalToGo posteam DefensiveTeam  PlayAttempted  \
# 0        30.0        0       0.0     PIT           TEN              1
# 1        58.0       10       0.0     PIT           TEN              1
# 2        53.0        5       0.0     PIT           TEN              1
# 3        56.0        8       0.0     PIT           TEN              1
# 4        56.0        8       0.0     PIT           TEN              1
#
#    ScoreDiff  AbsScoreDiff HomeTeam AwayTeam  Timeout_Indicator Timeout_Team  \
# 0        0.0           0.0      PIT      TEN                  0          NaN
# 1        0.0           0.0      PIT      TEN                  0          NaN
# 2        0.0           0.0      PIT      TEN                  0          NaN
# 3        0.0           0.0      PIT      TEN                  0          NaN
# 4        0.0           0.0      PIT      TEN                  0          NaN
#
#    posteam_timeouts_pre  HomeTimeouts_Remaining_Pre  \
# 0                     3                           3
# 1                     3                           3
# 2                     3                           3
# 3                     3                           3
# 4                     3                           3
#
#    AwayTimeouts_Remaining_Pre  HomeTimeouts_Remaining_Post  \
# 0                           3                            3
# 1                           3                            3
# 2                           3                            3
# 3                           3                            3
# 4                           3                            3
#
#    AwayTimeouts_Remaining_Post       EPA  Season
# 0                            3  2.014474    2009
# 1                            3  0.077907    2009
# 2                            3 -1.402760    2009
# 3                            3 -1.712583    2009
# 4                            3  2.097796    2009

# %%
# Remove all NaNs that are associated with end of quarter/half/game/etc.
df_clean = df_clean[df_clean['down'].notna()]
df_clean = df_clean[df_clean['PlayTimeDiff'].notna()]
df_clean = df_clean[df_clean['EPA'].notna()]

# Clean string identifiers from dataframe and create integer identifiers
# Attribute timeouts to 'posteam' or 'DefensiveTeam' instead of team name
df_clean['timeout_by_offense'] = (df_clean['Timeout_Team'] == df_clean['posteam']).astype(int)
df_clean['timeout_by_defense'] = (df_clean['Timeout_Team'] == df_clean['DefensiveTeam']).astype(int)
# Link possession team and defensive team to home or away team
df_clean["offense_is_home"] = (df_clean["posteam"] == df_clean["HomeTeam"]).astype(int)
df_clean["defense_is_home"] = (df_clean["DefensiveTeam"] == df_clean["HomeTeam"]).astype(int)
# Feature for model to attribute to different teams within the league
df_clean = pd.get_dummies(df_clean, columns = ["HomeTeam", "AwayTeam"], prefix=["home", "away"])
# Drop columns with string identifiers
df_clean = df_clean.drop(columns=['Timeout_Team', 'posteam', 'DefensiveTeam'])

# Print dataframe features to screen
df_clean.head()
# Out:
#        GameID  Drive  qtr  down  TimeUnder  TimeSecs  PlayTimeDiff  yrdln  \
# 1  2009091000      1    1   1.0         15    3593.0           7.0   42.0
# 2  2009091000      1    1   2.0         15    3556.0          37.0   47.0
# 3  2009091000      1    1   3.0         14    3515.0          41.0   44.0
# 4  2009091000      1    1   4.0         14    3507.0           8.0   44.0
# 5  2009091000      2    1   1.0         14    3496.0          11.0    2.0
#
#    yrdline100  ydstogo  GoalToGo  PlayAttempted  ScoreDiff  AbsScoreDiff  \
# 1        58.0       10       0.0              1        0.0           0.0
# 2        53.0        5       0.0              1        0.0           0.0
# 3        56.0        8       0.0              1        0.0           0.0
# 4        56.0        8       0.0              1        0.0           0.0
# 5        98.0       10       0.0              1        0.0           0.0
#
#    Timeout_Indicator  posteam_timeouts_pre  HomeTimeouts_Remaining_Pre  \
# 1                  0                     3                           3
# 2                  0                     3                           3
# 3                  0                     3                           3
# 4                  0                     3                           3
# 5                  0                     3                           3
#
#    AwayTimeouts_Remaining_Pre  HomeTimeouts_Remaining_Post  \
# 1                           3                            3
# 2                           3                            3
# 3                           3                            3
# 4                           3                            3
# 5                           3                            3
#
#    AwayTimeouts_Remaining_Post       EPA  Season  timeout_by_offense  \
# 1                            3  0.077907    2009                   0
# 2                            3 -1.402760    2009                   0
# 3                            3 -1.712583    2009                   0
# 4                            3  2.097796    2009                   0
# 5                            3 -0.696302    2009                   0
#
#    timeout_by_defense  offense_is_home  defense_is_home  home_ARI  home_ATL  \
# 1                   0                1                0     False     False
# 2                   0                1                0     False     False
# 3                   0                1                0     False     False
# 4                   0                1                0     False     False
# 5                   0                0                1     False     False
#
#    home_BAL  home_BUF  home_CAR  home_CHI  home_CIN  home_CLE  home_DAL  \
# 1     False     False     False     False     False     False     False
# 2     False     False     False     False     False     False     False
# 3     False     False     False     False     False     False     False
# 4     False     False     False     False     False     False     False
# 5     False     False     False     False     False     False     False
#
#    home_DEN  home_DET  home_GB  home_HOU  home_IND  home_JAC  home_JAX  \
# 1     False     False    False     False     False     False     False
# 2     False     False    False     False     False     False     False
# 3     False     False    False     False     False     False     False
# 4     False     False    False     False     False     False     False
# 5     False     False    False     False     False     False     False
#
#    home_KC  home_LA  home_LAC  home_MIA  home_MIN  home_NE  home_NO  home_NYG  \
# 1    False    False     False     False     False    False    False     False
# 2    False    False     False     False     False    False    False     False
# 3    False    False     False     False     False    False    False     False
# 4    False    False     False     False     False    False    False     False
# 5    False    False     False     False     False    False    False     False
#
#    home_NYJ  home_OAK  home_PHI  home_PIT  home_SD  home_SEA  home_SF  \
# 1     False     False     False      True    False     False    False
# 2     False     False     False      True    False     False    False
# 3     False     False     False      True    False     False    False
# 4     False     False     False      True    False     False    False
# 5     False     False     False      True    False     False    False
#
#    home_STL  home_TB  home_TEN  home_WAS  away_ARI  away_ATL  away_BAL  \
# 1     False    False     False     False     False     False     False
# 2     False    False     False     False     False     False     False
# 3     False    False     False     False     False     False     False
# 4     False    False     False     False     False     False     False
# 5     False    False     False     False     False     False     False
#
#    away_BUF  away_CAR  away_CHI  away_CIN  away_CLE  away_DAL  away_DEN  \
# 1     False     False     False     False     False     False     False
# 2     False     False     False     False     False     False     False
# 3     False     False     False     False     False     False     False
# 4     False     False     False     False     False     False     False
# 5     False     False     False     False     False     False     False
#
#    away_DET  away_GB  away_HOU  away_IND  away_JAC  away_JAX  away_KC  \
# 1     False    False     False     False     False     False    False
# 2     False    False     False     False     False     False    False
# 3     False    False     False     False     False     False    False
# 4     False    False     False     False     False     False    False
# 5     False    False     False     False     False     False    False
#
#    away_LA  away_LAC  away_MIA  away_MIN  away_NE  away_NO  away_NYG  \
# 1    False     False     False     False    False    False     False
# 2    False     False     False     False    False    False     False
# 3    False     False     False     False    False    False     False
# 4    False     False     False     False    False    False     False
# 5    False     False     False     False    False    False     False
#
#    away_NYJ  away_OAK  away_PHI  away_PIT  away_SD  away_SEA  away_SF  \
# 1     False     False     False     False    False     False    False
# 2     False     False     False     False    False     False    False
# 3     False     False     False     False    False     False    False
# 4     False     False     False     False    False     False    False
# 5     False     False     False     False    False     False    False
#
#    away_STL  away_TB  away_TEN  away_WAS
# 1     False    False      True     False
# 2     False    False      True     False
# 3     False    False      True     False
# 4     False    False      True     False
# 5     False    False      True     False

# %%
# Ensure all NaNs have been removed from dataframe
df_clean.isna().sum()
# Out:
# GameID       0
# Drive        0
# qtr          0
# down         0
# TimeUnder    0
#             ..
# away_SF      0
# away_STL     0
# away_TB      0
# away_TEN     0
# away_WAS     0
# Length: 96, dtype: int64

# %%
# Print number of dataframe points
print(f"Number of rows in dataframe: {len(df_clean)}")
# Out:
# Number of rows in dataframe: 346339

# %%
from sklearn.model_selection import train_test_split

# Identify total number of games contained within dataframe
game_ids = df_clean["GameID"].unique()
print(f"Total number of games played: {len(game_ids)}")

# Split on game_ids
train_ids, test_ids = train_test_split(game_ids, test_size=0.15, random_state=42)
train_ids, val_ids = train_test_split(train_ids, test_size=.1765, random_state=42)

# Validate train, test and val set sizes
print(f"Number of games in train set: {len(train_ids)}")
print(f"Number of games in val set: {len(val_ids)}")
print(f"Number of games in test set: {len(test_ids)}")
# Out:
# Total number of games played: 2304
# Number of games in train set: 1612
# Number of games in val set: 346
# Number of games in test set: 346

# %%
# Ensure no play from a game appears in more than one subset, each subset contains entire games, and validation and test subsets are unseen
train_df = df_clean[df_clean['GameID'].isin(train_ids)]
val_df = df_clean[df_clean['GameID'].isin(val_ids)]
test_df = df_clean[df_clean['GameID'].isin(test_ids)]

# %%
# Define target variable and feature variables
target_col = 'EPA'
feature_cols = [col for col in df_clean.columns if col != target_col]

# %%
# Extract y from datafame for train, val, and test
X_train = train_df[feature_cols]
y_train = train_df[target_col]

X_val = val_df[feature_cols]
y_val = val_df[target_col]

X_test = test_df[feature_cols]
y_test = test_df[target_col]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Normalize training data
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
import keras
from keras import layers
from keras.layers import Flatten
from keras.layers import Dense

def create_model():
  model = keras.Sequential([
      Dense(4, activation='tanh', input_shape=[len(feature_cols)]),
      Dense(6, activation='tanh'),
      Dense(1, activation='linear')
  ])

  model.compile(
      optimizer='adam',
      loss='mse',
      metrics=['mae', 'mse']
      )

  return model

model = create_model()

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 421 (1.64 KB)
#  Trainable params: 421 (1.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import os

checkpoint_path = "training_1/cp.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)
os.makedirs(checkpoint_dir, exist_ok=True)

cp_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    save_best_only=True,
    verbose=1
    )

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=7,
                                           restore_best_weights=True
                                           )

os.listdir(checkpoint_dir)

history = model.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    batch_size=256,
    validation_data=(X_val_scaled, y_val),
    callbacks=[cp_callback, early_stop]
    )
# Out:
# Epoch 1/100
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3641 - mae: 1.0904 - mse: 2.3641
# Epoch 1: val_loss improved from inf to 1.96455, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 2.3638 - mae: 1.0904 - mse: 2.3638 - val_loss: 1.9645 - val_mae: 0.9665 - val_mse: 1.9645
# Epoch 2/100
# 943/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9417 - mae: 0.9619 - mse: 1.9417
# Epoch 2: val_loss improved from 1.96455 to 1.95713, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9417 - mae: 0.9620 - mse: 1.9417 - val_loss: 1.9571 - val_mae: 0.9631 - val_mse: 1.9571
# Epoch 3/100
# 939/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9319 - mae: 0.9581 - mse: 1.9319
# Epoch 3: val_loss improved from 1.95713 to 1.95658, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9321 - mae: 0.9581 - mse: 1.9321 - val_loss: 1.9566 - val_mae: 0.9672 - val_mse: 1.9566
# Epoch 4/100
# 939/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9642 - mae: 0.9635 - mse: 1.9642
# Epoch 4: val_loss did not improve from 1.95658
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9641 - mae: 0.9635 - mse: 1.9641 - val_loss: 1.9581 - val_mae: 0.9653 - val_mse: 1.9581
# Epoch 5/100
# 943/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9628 - mae: 0.9649 - mse: 1.9628
# Epoch 5: val_loss improved from 1.95658 to 1.95556, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9627 - mae: 0.9649 - mse: 1.9627 - val_loss: 1.9556 - val_mae: 0.9639 - val_mse: 1.9556
# Epoch 6/100
# 939/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9679 - mae: 0.9627 - mse: 1.9679
# Epoch 6: val_loss improved from 1.95556 to 1.95555, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9677 - mae: 0.9627 - mse: 1.9677 - val_loss: 1.9556 - val_mae: 0.9619 - val_mse: 1.9556
# Epoch 7/100
# 938/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9388 - mae: 0.9606 - mse: 1.9388
# Epoch 7: val_loss improved from 1.95555 to 1.95542, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9389 - mae: 0.9607 - mse: 1.9389 - val_loss: 1.9554 - val_mae: 0.9668 - val_mse: 1.9554
# Epoch 8/100
# 939/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9506 - mae: 0.9635 - mse: 1.9506
# Epoch 8: val_loss did not improve from 1.95542
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 1.9506 - mae: 0.9635 - mse: 1.9506 - val_loss: 1.9581 - val_mae: 0.9595 - val_mse: 1.9581
# Epoch 9/100
# 939/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9506 - mae: 0.9591 - mse: 1.9506
# Epoch 9: val_loss did not improve from 1.95542
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9506 - mae: 0.9591 - mse: 1.9506 - val_loss: 1.9566 - val_mae: 0.9616 - val_mse: 1.9566
# Epoch 10/100
# 940/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9558 - mae: 0.9629 - mse: 1.9558
# Epoch 10: val_loss did not improve from 1.95542
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9557 - mae: 0.9629 - mse: 1.9557 - val_loss: 1.9571 - val_mae: 0.9642 - val_mse: 1.9571
# Epoch 11/100
# 934/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9375 - mae: 0.9571 - mse: 1.9375
# Epoch 11: val_loss did not improve from 1.95542
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9377 - mae: 0.9571 - mse: 1.9377 - val_loss: 1.9563 - val_mae: 0.9661 - val_mse: 1.9563
# Epoch 12/100
# 937/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9455 - mae: 0.9602 - mse: 1.9455
# Epoch 12: val_loss did not improve from 1.95542
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9456 - mae: 0.9603 - mse: 1.9456 - val_loss: 1.9556 - val_mae: 0.9648 - val_mse: 1.9556
# Epoch 13/100
# 931/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9584 - mae: 0.9629 - mse: 1.9584
# Epoch 13: val_loss improved from 1.95542 to 1.95518, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9582 - mae: 0.9629 - mse: 1.9582 - val_loss: 1.9552 - val_mae: 0.9683 - val_mse: 1.9552
# Epoch 14/100
# 946/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9405 - mae: 0.9614 - mse: 1.9405
# Epoch 14: val_loss did not improve from 1.95518
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9405 - mae: 0.9614 - mse: 1.9405 - val_loss: 1.9564 - val_mae: 0.9666 - val_mse: 1.9564
# Epoch 15/100
# 930/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9623 - mae: 0.9653 - mse: 1.9623
# Epoch 15: val_loss did not improve from 1.95518
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9621 - mae: 0.9652 - mse: 1.9621 - val_loss: 1.9556 - val_mae: 0.9659 - val_mse: 1.9556
# Epoch 16/100
# 946/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9629 - mae: 0.9659 - mse: 1.9629
# Epoch 16: val_loss did not improve from 1.95518
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9629 - mae: 0.9659 - mse: 1.9629 - val_loss: 1.9563 - val_mae: 0.9640 - val_mse: 1.9563
# Epoch 17/100
# 940/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9574 - mae: 0.9634 - mse: 1.9574
# Epoch 17: val_loss did not improve from 1.95518
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9574 - mae: 0.9634 - mse: 1.9574 - val_loss: 1.9554 - val_mae: 0.9651 - val_mse: 1.9554
# Epoch 18/100
# 937/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9473 - mae: 0.9638 - mse: 1.9473
# Epoch 18: val_loss did not improve from 1.95518
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9473 - mae: 0.9637 - mse: 1.9473 - val_loss: 1.9570 - val_mae: 0.9643 - val_mse: 1.9570
# Epoch 19/100
# 929/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9522 - mae: 0.9620 - mse: 1.9522
# Epoch 19: val_loss did not improve from 1.95518
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9521 - mae: 0.9620 - mse: 1.9521 - val_loss: 1.9555 - val_mae: 0.9640 - val_mse: 1.9555
# Epoch 20/100
# 937/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9594 - mae: 0.9632 - mse: 1.9594
# Epoch 20: val_loss improved from 1.95518 to 1.95459, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9592 - mae: 0.9632 - mse: 1.9592 - val_loss: 1.9546 - val_mae: 0.9663 - val_mse: 1.9546
# Epoch 21/100
# 936/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9386 - mae: 0.9599 - mse: 1.9386
# Epoch 21: val_loss did not improve from 1.95459
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9387 - mae: 0.9600 - mse: 1.9387 - val_loss: 1.9551 - val_mae: 0.9656 - val_mse: 1.9551
# Epoch 22/100
# 938/947 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9526 - mae: 0.9617 - mse: 1.9526
# Epoch 22: val_loss did not improve from 1.95459
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.9526 - mae: 0.9617 - mse: 1.9526 - val_loss: 1.9549 - val_mae: 0.9635 - val_mse: 1.9549
# Epoch 23/100
# 928/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9453 - mae: 0.9612 - mse: 1.9453
# Epoch 23: val_loss did not improve from 1.95459
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9453 - mae: 0.9612 - mse: 1.9453 - val_loss: 1.9546 - val_mae: 0.9651 - val_mse: 1.9546
# Epoch 24/100
# 938/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9533 - mae: 0.9627 - mse: 1.9533
# Epoch 24: val_loss improved from 1.95459 to 1.95455, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9532 - mae: 0.9627 - mse: 1.9532 - val_loss: 1.9545 - val_mae: 0.9643 - val_mse: 1.9545
# Epoch 25/100
# 929/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9517 - mae: 0.9611 - mse: 1.9517
# Epoch 25: val_loss did not improve from 1.95455
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9516 - mae: 0.9612 - mse: 1.9516 - val_loss: 1.9548 - val_mae: 0.9665 - val_mse: 1.9548
# Epoch 26/100
# 938/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9547 - mae: 0.9647 - mse: 1.9547
# Epoch 26: val_loss did not improve from 1.95455
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9545 - mae: 0.9647 - mse: 1.9545 - val_loss: 1.9550 - val_mae: 0.9643 - val_mse: 1.9550
# Epoch 27/100
# 931/947 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9276 - mae: 0.9594 - mse: 1.9276
# Epoch 27: val_loss did not improve from 1.95455
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9279 - mae: 0.9594 - mse: 1.9279 - val_loss: 1.9564 - val_mae: 0.9640 - val_mse: 1.9564
# Epoch 28/100
# 942/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9446 - mae: 0.9595 - mse: 1.9446
# Epoch 28: val_loss did not improve from 1.95455
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9446 - mae: 0.9595 - mse: 1.9446 - val_loss: 1.9551 - val_mae: 0.9626 - val_mse: 1.9551
# Epoch 29/100
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9467 - mae: 0.9608 - mse: 1.9467
# Epoch 29: val_loss improved from 1.95455 to 1.95452, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9467 - mae: 0.9608 - mse: 1.9467 - val_loss: 1.9545 - val_mae: 0.9683 - val_mse: 1.9545
# Epoch 30/100
# 928/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9444 - mae: 0.9622 - mse: 1.9444
# Epoch 30: val_loss did not improve from 1.95452
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.9444 - mae: 0.9621 - mse: 1.9444 - val_loss: 1.9558 - val_mae: 0.9639 - val_mse: 1.9558
# Epoch 31/100
# 935/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9407 - mae: 0.9619 - mse: 1.9407
# Epoch 31: val_loss did not improve from 1.95452
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9407 - mae: 0.9619 - mse: 1.9407 - val_loss: 1.9566 - val_mae: 0.9603 - val_mse: 1.9566
# Epoch 32/100
# 927/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9563 - mae: 0.9624 - mse: 1.9563
# Epoch 32: val_loss improved from 1.95452 to 1.95444, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9560 - mae: 0.9624 - mse: 1.9560 - val_loss: 1.9544 - val_mae: 0.9643 - val_mse: 1.9544
# Epoch 33/100
# 936/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9500 - mae: 0.9612 - mse: 1.9500
# Epoch 33: val_loss did not improve from 1.95444
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9499 - mae: 0.9612 - mse: 1.9499 - val_loss: 1.9546 - val_mae: 0.9647 - val_mse: 1.9546
# Epoch 34/100
# 928/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9393 - mae: 0.9615 - mse: 1.9393
# Epoch 34: val_loss did not improve from 1.95444
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9394 - mae: 0.9614 - mse: 1.9394 - val_loss: 1.9549 - val_mae: 0.9665 - val_mse: 1.9549
# Epoch 35/100
# 929/947 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9572 - mae: 0.9613 - mse: 1.9572
# Epoch 35: val_loss improved from 1.95444 to 1.95411, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9569 - mae: 0.9613 - mse: 1.9569 - val_loss: 1.9541 - val_mae: 0.9647 - val_mse: 1.9541
# Epoch 36/100
# 936/947 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9518 - mae: 0.9634 - mse: 1.9518
# Epoch 36: val_loss improved from 1.95411 to 1.95402, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9517 - mae: 0.9634 - mse: 1.9517 - val_loss: 1.9540 - val_mae: 0.9654 - val_mse: 1.9540
# Epoch 37/100
# 938/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9506 - mae: 0.9599 - mse: 1.9506
# Epoch 37: val_loss did not improve from 1.95402
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9506 - mae: 0.9599 - mse: 1.9506 - val_loss: 1.9540 - val_mae: 0.9657 - val_mse: 1.9540
# Epoch 38/100
# 944/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9378 - mae: 0.9584 - mse: 1.9378
# Epoch 38: val_loss improved from 1.95402 to 1.95363, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9378 - mae: 0.9584 - mse: 1.9378 - val_loss: 1.9536 - val_mae: 0.9637 - val_mse: 1.9536
# Epoch 39/100
# 935/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9232 - mae: 0.9582 - mse: 1.9232
# Epoch 39: val_loss did not improve from 1.95363
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9235 - mae: 0.9582 - mse: 1.9235 - val_loss: 1.9550 - val_mae: 0.9654 - val_mse: 1.9550
# Epoch 40/100
# 928/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9335 - mae: 0.9604 - mse: 1.9335
# Epoch 40: val_loss did not improve from 1.95363
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9337 - mae: 0.9604 - mse: 1.9337 - val_loss: 1.9547 - val_mae: 0.9617 - val_mse: 1.9547
# Epoch 41/100
# 933/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9383 - mae: 0.9588 - mse: 1.9383
# Epoch 41: val_loss did not improve from 1.95363
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9384 - mae: 0.9588 - mse: 1.9384 - val_loss: 1.9561 - val_mae: 0.9615 - val_mse: 1.9561
# Epoch 42/100
# 937/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9602 - mae: 0.9642 - mse: 1.9602
# Epoch 42: val_loss improved from 1.95363 to 1.95306, saving model to training_1/cp.weights.h5
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9600 - mae: 0.9641 - mse: 1.9600 - val_loss: 1.9531 - val_mae: 0.9643 - val_mse: 1.9531
# Epoch 43/100
# 943/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9616 - mae: 0.9628 - mse: 1.9616
# Epoch 43: val_loss did not improve from 1.95306
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9615 - mae: 0.9628 - mse: 1.9615 - val_loss: 1.9537 - val_mae: 0.9635 - val_mse: 1.9537
# Epoch 44/100
# 932/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9284 - mae: 0.9594 - mse: 1.9284
# Epoch 44: val_loss did not improve from 1.95306
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9287 - mae: 0.9594 - mse: 1.9287 - val_loss: 1.9538 - val_mae: 0.9647 - val_mse: 1.9538
# Epoch 45/100
# 934/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9395 - mae: 0.9589 - mse: 1.9395
# Epoch 45: val_loss did not improve from 1.95306
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9395 - mae: 0.9589 - mse: 1.9395 - val_loss: 1.9550 - val_mae: 0.9631 - val_mse: 1.9550
# Epoch 46/100
# 945/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9546 - mae: 0.9600 - mse: 1.9546
# Epoch 46: val_loss did not improve from 1.95306
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9546 - mae: 0.9600 - mse: 1.9546 - val_loss: 1.9547 - val_mae: 0.9669 - val_mse: 1.9547
# Epoch 47/100
# 939/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9315 - mae: 0.9584 - mse: 1.9315
# Epoch 47: val_loss did not improve from 1.95306
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9316 - mae: 0.9584 - mse: 1.9316 - val_loss: 1.9537 - val_mae: 0.9657 - val_mse: 1.9537
# Epoch 48/100
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9519 - mae: 0.9618 - mse: 1.9519
# Epoch 48: val_loss did not improve from 1.95306
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.9519 - mae: 0.9618 - mse: 1.9519 - val_loss: 1.9537 - val_mae: 0.9648 - val_mse: 1.9537
# Epoch 49/100
# 945/947 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9431 - mae: 0.9608 - mse: 1.9431
# Epoch 49: val_loss did not improve from 1.95306
# 947/947 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9431 - mae: 0.9608 - mse: 1.9431 - val_loss: 1.9554 - val_mae: 0.9666 - val_mse: 1.9554

# %%
history_dict = history.history
print(history_dict.keys())
# Out:
# dict_keys(['loss', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse'])

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'r--', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.xticks(epochs)
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import numpy as np

# Pick a random subset of validation data for permutation importance
rng = np.random.default_rng(42)
n_samples = min(10000, X_val_scaled.shape[0])

indices = rng.choice(X_val_scaled.shape[0], size=n_samples, replace=False)

X_val_sub = X_val_scaled[indices]
y_val_sub = y_val.iloc[indices] if hasattr(y_val, "iloc") else y_val[indices]

# %%
# define MAE scoring function for permutation importance
from sklearn.metrics import mean_absolute_error

def mae_scorer(model, X, y):
  y_pred = model.predict(X, batch_size=4096, verbose=0)
  return -mean_absolute_error(y, y_pred)  # negative because higher is better

mae_scorer(model, X_val_scaled, y_val)
# Out:
# -0.9643400306103883

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(
    model,
    X_val_sub,
    y_val_sub,
    scoring=mae_scorer,
    n_repeats=5,
    random_state=42,
    n_jobs=1
    )

importance_df = pd.DataFrame({
    "feature": feature_cols,
    "importance": result.importances_mean
    })

importance_df.sort_values(by="importance", ascending=False, inplace=True)

top_k = 20
plt.figure(figsize=(8,6))
plt.barh(importance_df["feature"].head(top_k)[::-1],
         importance_df["importance"].head(top_k)[::-1])
plt.xlabel("Mean drop in validation score")
plt.title("Permutation feature importance")
# plt.tight_layout()
plt.show()

# %%
results = model.evaluate(X_test_scaled, y_test, batch_size=256)
print("test loss, test acc:", results)
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.9569 - mae: 0.9616 - mse: 1.9569
# test loss, test acc: [1.9438692331314087, 0.9637676477432251, 1.9438692331314087]

# %%
# Obtain EPA predictions per play
y_pred = model.predict(X_test_scaled)
# Out:
# 1622/1622 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %%
# Add predictions back into test dataframe
test_df = test_df.copy()
test_df['EPA_pred'] = y_pred
test_df['EPA_true'] = y_test

# %%
# Aggregate per game
game_results = test_df.groupby("GameID")[["EPA_true", "EPA_pred"]].sum()
# Mean absolute EPA error per game
game_results["game_MAE"] = (game_results["EPA_true"] - game_results["EPA_pred"]).abs()
overall_game_MAE = game_results["game_MAE"].mean()
print(f"Overall game MAE: {overall_game_MAE}")
# Out:
# Overall game MAE: 15.726647500298288
