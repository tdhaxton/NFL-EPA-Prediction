# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("maxhorowitz/nflplaybyplay2009to2016")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'nflplaybyplay2009to2016' dataset.
# Path to dataset files: /kaggle/input/nflplaybyplay2009to2016

# %%
import pandas as pd

# Import dataframe
df = pd.read_csv(path + "/NFL Play by Play 2009-2017 (v4).csv")
df.head(10)
# Out:
# /tmp/ipython-input-4024366084.py:4: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path + "/NFL Play by Play 2009-2017 (v4).csv")
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# 5  2009-09-10  2009091000      2    1   1.0  13:16         14    3496.0
# 6  2009-09-10  2009091000      2    1   2.0  12:40         13    3460.0
# 7  2009-09-10  2009091000      2    1   3.0  12:11         13    3431.0
# 8  2009-09-10  2009091000      2    1   4.0  11:34         12    3394.0
# 9  2009-09-10  2009091000      3    1   1.0  11:24         12    3384.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
# 5          11.0         TEN  ...       NaN     0.558929     0.441071
# 6          36.0         TEN  ...  0.163935     0.578453     0.421547
# 7          29.0         TEN  ...       NaN     0.582881     0.417119
# 8          37.0         TEN  ...       NaN     0.617544     0.382456
# 9          10.0         TEN  ...  0.541602     0.591489     0.408511
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.546433      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.551088      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.510793      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.461217      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.558929      0.441071  0.461217  0.097712       NaN       NaN    2009
# 5      0.578453      0.421547  0.441071 -0.019524       NaN       NaN    2009
# 6      0.582881      0.417119  0.421547 -0.004427 -0.010456  0.006029    2009
# 7      0.617544      0.382456  0.417119 -0.034663       NaN       NaN    2009
# 8      0.591489      0.408511  0.382456  0.026054       NaN       NaN    2009
# 9      0.585405      0.414595  0.591489 -0.006084 -0.024526  0.018442    2009
#
# [10 rows x 102 columns]

# %%
# Print list of columns and number of columns in dataframe for cleaning
columns = list(df.columns)
print(columns)
print(f"Number of columns in dataframe: {len(columns)}")
# Out:
# ['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder', 'TimeSecs', 'PlayTimeDiff', 'SideofField', 'yrdln', 'yrdline100', 'ydstogo', 'ydsnet', 'GoalToGo', 'FirstDown', 'posteam', 'DefensiveTeam', 'desc', 'PlayAttempted', 'Yards.Gained', 'sp', 'Touchdown', 'ExPointResult', 'TwoPointConv', 'DefTwoPoint', 'Safety', 'Onsidekick', 'PuntResult', 'PlayType', 'Passer', 'Passer_ID', 'PassAttempt', 'PassOutcome', 'PassLength', 'AirYards', 'YardsAfterCatch', 'QBHit', 'PassLocation', 'InterceptionThrown', 'Interceptor', 'Rusher', 'Rusher_ID', 'RushAttempt', 'RunLocation', 'RunGap', 'Receiver', 'Receiver_ID', 'Reception', 'ReturnResult', 'Returner', 'BlockingPlayer', 'Tackler1', 'Tackler2', 'FieldGoalResult', 'FieldGoalDistance', 'Fumble', 'RecFumbTeam', 'RecFumbPlayer', 'Sack', 'Challenge.Replay', 'ChalReplayResult', 'Accepted.Penalty', 'PenalizedTeam', 'PenaltyType', 'PenalizedPlayer', 'Penalty.Yards', 'PosTeamScore', 'DefTeamScore', 'ScoreDiff', 'AbsScoreDiff', 'HomeTeam', 'AwayTeam', 'Timeout_Indicator', 'Timeout_Team', 'posteam_timeouts_pre', 'HomeTimeouts_Remaining_Pre', 'AwayTimeouts_Remaining_Pre', 'HomeTimeouts_Remaining_Post', 'AwayTimeouts_Remaining_Post', 'No_Score_Prob', 'Opp_Field_Goal_Prob', 'Opp_Safety_Prob', 'Opp_Touchdown_Prob', 'Field_Goal_Prob', 'Safety_Prob', 'Touchdown_Prob', 'ExPoint_Prob', 'TwoPoint_Prob', 'ExpPts', 'EPA', 'airEPA', 'yacEPA', 'Home_WP_pre', 'Away_WP_pre', 'Home_WP_post', 'Away_WP_post', 'Win_Prob', 'WPA', 'airWPA', 'yacWPA', 'Season']
# Number of columns in dataframe: 102

# %%
# Drop columns from dataframe that contain information from the current play
cols_to_drop = ["Date", "time", "SideofField", "ydsnet", "FirstDown", "DefTwoPoint", "Passer", "Passer_ID", "ExpPts", "WPA", "No_Score_Prob", "Opp_Field_Goal_Prob", "Opp_Safety_Prob", "Opp_Touchdown_Prob", "Field_Goal_Prob", "Safety_Prob", "Touchdown_Prob", "ExPoint_Prob", "TwoPoint_Prob", "airEPA", "yacEPA", "Home_WP_pre", "Away_WP_pre", "Home_WP_post", "Away_WP_post", "Win_Prob", "airWPA", "yacWPA", "desc", "Yards.Gained", "Touchdown", "Safety", "Onsidekick", "PuntResult", "PlayType", "PassLength", "PassAttempt", "PassOutcome", "AirYards", "YardsAfterCatch", "QBHit", "PassLocation", "InterceptionThrown", "Interceptor", "Rusher", "Rusher_ID", "RushAttempt", "RunLocation", "RunGap", "Receiver", "Receiver_ID", "Reception", "ReturnResult", "Returner", "BlockingPlayer", "Tackler1", "Tackler2", "FieldGoalResult", "FieldGoalDistance", "Fumble", "RecFumbTeam", "RecFumbPlayer", "Sack", "Challenge.Replay", "ChalReplayResult", "Accepted.Penalty", "PenalizedTeam", "PenaltyType", "PenalizedPlayer", "Penalty.Yards", "PosTeamScore", "DefTeamScore", "ExPointResult", "TwoPointConv", "sp"]
df_clean = df.drop(columns=cols_to_drop, axis=1)

columns = list(df_clean.columns)
print(columns)
print(f"Number of columns in dataframe: {len(columns)}")
# Out:
# ['GameID', 'Drive', 'qtr', 'down', 'TimeUnder', 'TimeSecs', 'PlayTimeDiff', 'yrdln', 'yrdline100', 'ydstogo', 'GoalToGo', 'posteam', 'DefensiveTeam', 'PlayAttempted', 'ScoreDiff', 'AbsScoreDiff', 'HomeTeam', 'AwayTeam', 'Timeout_Indicator', 'Timeout_Team', 'posteam_timeouts_pre', 'HomeTimeouts_Remaining_Pre', 'AwayTimeouts_Remaining_Pre', 'HomeTimeouts_Remaining_Post', 'AwayTimeouts_Remaining_Post', 'EPA', 'Season']
# Number of columns in dataframe: 27

# %%
pd.set_option('display.max_columns', None)
df_clean.head()
# Out:
#        GameID  Drive  qtr  down  TimeUnder  TimeSecs  PlayTimeDiff  yrdln  \
# 0  2009091000      1    1   NaN         15    3600.0           0.0   30.0
# 1  2009091000      1    1   1.0         15    3593.0           7.0   42.0
# 2  2009091000      1    1   2.0         15    3556.0          37.0   47.0
# 3  2009091000      1    1   3.0         14    3515.0          41.0   44.0
# 4  2009091000      1    1   4.0         14    3507.0           8.0   44.0
#
#    yrdline100  ydstogo  GoalToGo posteam DefensiveTeam  PlayAttempted  \
# 0        30.0        0       0.0     PIT           TEN              1
# 1        58.0       10       0.0     PIT           TEN              1
# 2        53.0        5       0.0     PIT           TEN              1
# 3        56.0        8       0.0     PIT           TEN              1
# 4        56.0        8       0.0     PIT           TEN              1
#
#    ScoreDiff  AbsScoreDiff HomeTeam AwayTeam  Timeout_Indicator Timeout_Team  \
# 0        0.0           0.0      PIT      TEN                  0          NaN
# 1        0.0           0.0      PIT      TEN                  0          NaN
# 2        0.0           0.0      PIT      TEN                  0          NaN
# 3        0.0           0.0      PIT      TEN                  0          NaN
# 4        0.0           0.0      PIT      TEN                  0          NaN
#
#    posteam_timeouts_pre  HomeTimeouts_Remaining_Pre  \
# 0                     3                           3
# 1                     3                           3
# 2                     3                           3
# 3                     3                           3
# 4                     3                           3
#
#    AwayTimeouts_Remaining_Pre  HomeTimeouts_Remaining_Post  \
# 0                           3                            3
# 1                           3                            3
# 2                           3                            3
# 3                           3                            3
# 4                           3                            3
#
#    AwayTimeouts_Remaining_Post       EPA  Season
# 0                            3  2.014474    2009
# 1                            3  0.077907    2009
# 2                            3 -1.402760    2009
# 3                            3 -1.712583    2009
# 4                            3  2.097796    2009

# %%
# Remove all NaNs that are associated with end of quarter/half/game/etc.
df_clean = df_clean[df_clean['down'].notna()]
df_clean = df_clean[df_clean['PlayTimeDiff'].notna()]
df_clean = df_clean[df_clean['EPA'].notna()]

# Clean string identifiers from dataframe and create integer identifiers
# Attribute timeouts to 'posteam' or 'DefensiveTeam' instead of team name
df_clean['timeout_by_offense'] = (df_clean['Timeout_Team'] == df_clean['posteam']).astype(int)
df_clean['timeout_by_defense'] = (df_clean['Timeout_Team'] == df_clean['DefensiveTeam']).astype(int)
# Link possession team and defensive team to home or away team
df_clean["offense_is_home"] = (df_clean["posteam"] == df_clean["HomeTeam"]).astype(int)
df_clean["defense_is_home"] = (df_clean["DefensiveTeam"] == df_clean["HomeTeam"]).astype(int)
# Drop columns with string identifiers
df_clean = df_clean.drop(columns=['Timeout_Team', 'posteam', 'DefensiveTeam'])

# Print dataframe features to screen
df_clean.head()
# Out:
#        GameID  Drive  qtr  down  TimeUnder  TimeSecs  PlayTimeDiff  yrdln  \
# 1  2009091000      1    1   1.0         15    3593.0           7.0   42.0
# 2  2009091000      1    1   2.0         15    3556.0          37.0   47.0
# 3  2009091000      1    1   3.0         14    3515.0          41.0   44.0
# 4  2009091000      1    1   4.0         14    3507.0           8.0   44.0
# 5  2009091000      2    1   1.0         14    3496.0          11.0    2.0
#
#    yrdline100  ydstogo  GoalToGo  PlayAttempted  ScoreDiff  AbsScoreDiff  \
# 1        58.0       10       0.0              1        0.0           0.0
# 2        53.0        5       0.0              1        0.0           0.0
# 3        56.0        8       0.0              1        0.0           0.0
# 4        56.0        8       0.0              1        0.0           0.0
# 5        98.0       10       0.0              1        0.0           0.0
#
#   HomeTeam AwayTeam  Timeout_Indicator  posteam_timeouts_pre  \
# 1      PIT      TEN                  0                     3
# 2      PIT      TEN                  0                     3
# 3      PIT      TEN                  0                     3
# 4      PIT      TEN                  0                     3
# 5      PIT      TEN                  0                     3
#
#    HomeTimeouts_Remaining_Pre  AwayTimeouts_Remaining_Pre  \
# 1                           3                           3
# 2                           3                           3
# 3                           3                           3
# 4                           3                           3
# 5                           3                           3
#
#    HomeTimeouts_Remaining_Post  AwayTimeouts_Remaining_Post       EPA  Season  \
# 1                            3                            3  0.077907    2009
# 2                            3                            3 -1.402760    2009
# 3                            3                            3 -1.712583    2009
# 4                            3                            3  2.097796    2009
# 5                            3                            3 -0.696302    2009
#
#    timeout_by_offense  timeout_by_defense  offense_is_home  defense_is_home
# 1                   0                   0                1                0
# 2                   0                   0                1                0
# 3                   0                   0                1                0
# 4                   0                   0                1                0
# 5                   0                   0                0                1

# %%
# Clean all teams games that don't contain WAS in the HomeTeam or AwayTeam columns
team = "WAS"
df_wash = df_clean[
    (df_clean["HomeTeam"] == team) |
    (df_clean["AwayTeam"] == team)
].copy()

# Feature for model to attribute to different teams within the league
df_wash = pd.get_dummies(df_wash, columns = ["HomeTeam", "AwayTeam"], prefix=["home", "away"])
df_wash.head()
# Out:
#           GameID  Drive  qtr  down  TimeUnder  TimeSecs  PlayTimeDiff  yrdln  \
# 2068  2009091310      1    1   1.0         15    3595.0           5.0   22.0
# 2069  2009091310      1    1   2.0         15    3570.0          25.0   25.0
# 2070  2009091310      1    1   3.0         14    3523.0          47.0   29.0
# 2071  2009091310      1    1   1.0         14    3481.0          42.0   36.0
# 2072  2009091310      1    1   2.0         13    3473.0           8.0   36.0
#
#       yrdline100  ydstogo  GoalToGo  PlayAttempted  ScoreDiff  AbsScoreDiff  \
# 2068        78.0       10       0.0              1        0.0           0.0
# 2069        75.0        7       0.0              1        0.0           0.0
# 2070        71.0        3       0.0              1        0.0           0.0
# 2071        64.0       10       0.0              1        0.0           0.0
# 2072        64.0       10       0.0              1        0.0           0.0
#
#       Timeout_Indicator  posteam_timeouts_pre  HomeTimeouts_Remaining_Pre  \
# 2068                  0                     3                           3
# 2069                  0                     3                           3
# 2070                  0                     3                           3
# 2071                  0                     3                           3
# 2072                  0                     3                           3
#
#       AwayTimeouts_Remaining_Pre  HomeTimeouts_Remaining_Post  \
# 2068                           3                            3
# 2069                           3                            3
# 2070                           3                            3
# 2071                           3                            3
# 2072                           3                            3
#
#       AwayTimeouts_Remaining_Post       EPA  Season  timeout_by_offense  \
# 2068                            3 -0.285448    2009                   0
# 2069                            3 -0.012455    2009                   0
# 2070                            3  1.641027    2009                   0
# 2071                            3 -0.712342    2009                   0
# 2072                            3 -0.496560    2009                   0
#
#       timeout_by_defense  offense_is_home  defense_is_home  home_ARI  \
# 2068                   0                1                0     False
# 2069                   0                1                0     False
# 2070                   0                1                0     False
# 2071                   0                1                0     False
# 2072                   0                1                0     False
#
#       home_ATL  home_BAL  home_BUF  home_CAR  home_CHI  home_CIN  home_CLE  \
# 2068     False     False     False     False     False     False     False
# 2069     False     False     False     False     False     False     False
# 2070     False     False     False     False     False     False     False
# 2071     False     False     False     False     False     False     False
# 2072     False     False     False     False     False     False     False
#
#       home_DAL  home_DEN  home_DET  home_GB  home_HOU  home_IND  home_JAC  \
# 2068     False     False     False    False     False     False     False
# 2069     False     False     False    False     False     False     False
# 2070     False     False     False    False     False     False     False
# 2071     False     False     False    False     False     False     False
# 2072     False     False     False    False     False     False     False
#
#       home_KC  home_LA  home_LAC  home_MIA  home_MIN  home_NE  home_NO  \
# 2068    False    False     False     False     False    False    False
# 2069    False    False     False     False     False    False    False
# 2070    False    False     False     False     False    False    False
# 2071    False    False     False     False     False    False    False
# 2072    False    False     False     False     False    False    False
#
#       home_NYG  home_NYJ  home_OAK  home_PHI  home_PIT  home_SD  home_SEA  \
# 2068      True     False     False     False     False    False     False
# 2069      True     False     False     False     False    False     False
# 2070      True     False     False     False     False    False     False
# 2071      True     False     False     False     False    False     False
# 2072      True     False     False     False     False    False     False
#
#       home_SF  home_STL  home_TB  home_TEN  home_WAS  away_ARI  away_ATL  \
# 2068    False     False    False     False     False     False     False
# 2069    False     False    False     False     False     False     False
# 2070    False     False    False     False     False     False     False
# 2071    False     False    False     False     False     False     False
# 2072    False     False    False     False     False     False     False
#
#       away_BAL  away_BUF  away_CAR  away_CHI  away_CIN  away_CLE  away_DAL  \
# 2068     False     False     False     False     False     False     False
# 2069     False     False     False     False     False     False     False
# 2070     False     False     False     False     False     False     False
# 2071     False     False     False     False     False     False     False
# 2072     False     False     False     False     False     False     False
#
#       away_DEN  away_DET  away_GB  away_HOU  away_IND  away_JAC  away_KC  \
# 2068     False     False    False     False     False     False    False
# 2069     False     False    False     False     False     False    False
# 2070     False     False    False     False     False     False    False
# 2071     False     False    False     False     False     False    False
# 2072     False     False    False     False     False     False    False
#
#       away_MIA  away_MIN  away_NE  away_NO  away_NYG  away_NYJ  away_OAK  \
# 2068     False     False    False    False     False     False     False
# 2069     False     False    False    False     False     False     False
# 2070     False     False    False    False     False     False     False
# 2071     False     False    False    False     False     False     False
# 2072     False     False    False    False     False     False     False
#
#       away_PHI  away_PIT  away_SD  away_SEA  away_SF  away_STL  away_TB  \
# 2068     False     False    False     False    False     False    False
# 2069     False     False    False     False    False     False    False
# 2070     False     False    False     False    False     False    False
# 2071     False     False    False     False    False     False    False
# 2072     False     False    False     False    False     False    False
#
#       away_TEN  away_WAS
# 2068     False      True
# 2069     False      True
# 2070     False      True
# 2071     False      True
# 2072     False      True

# %%
# Ensure all NaNs have been removed from dataframe
pd.set_option('display.max_columns', None)
df_wash.isna().sum()
# Out:
# GameID       0
# Drive        0
# qtr          0
# down         0
# TimeUnder    0
#             ..
# away_SF      0
# away_STL     0
# away_TB      0
# away_TEN     0
# away_WAS     0
# Length: 92, dtype: int64

# %%
# Print number of dataframe points
print(f"Number of rows in dataframe: {len(df_clean)}")
# Out:
# Number of rows in dataframe: 346339

# %%
from sklearn.model_selection import train_test_split

# Identify total number of games contained within dataframe
game_ids = df_wash["GameID"].unique()
print(f"Total number of games played: {len(game_ids)}")
# Out:
# Total number of games played: 144

# %%
# Identify unique games, in order of first appearance
games_in_order = df_wash.drop_duplicates("GameID")["GameID"].tolist()

total_games = len(games_in_order)

train_count = int(total_games * 0.7)
val_count = int(total_games * 0.15)
test_count = total_games - train_count - val_count

# Split the game IDs
train_ids = games_in_order[:train_count]
val_ids = games_in_order[train_count:train_count + val_count]
test_ids = games_in_order[train_count + val_count:]

# Filter plays by GameID
train_df = df_wash[df_wash["GameID"].isin(train_ids)]
val_df = df_wash[df_wash["GameID"].isin(val_ids)]
test_df = df_wash[df_wash["GameID"].isin(test_ids)]

# Validate number of games in each split
print(f"Number of games in training set: {len(train_df['GameID'].unique())}")
print(f"Number of games in validation set: {len(val_df['GameID'].unique())}")
print(f"Number of games in test set: {len(test_df['GameID'].unique())}")
# Out:
# Number of games in training set: 100
# Number of games in validation set: 21
# Number of games in test set: 23

# %%
# Define target variable and feature variables
target_col = 'EPA'
feature_cols = [col for col in df_wash.columns if col != target_col]

# %%
# Extract y from datafame for train, val, and test
X_train = train_df[feature_cols]
y_train = train_df[target_col]

X_val = val_df[feature_cols]
y_val = val_df[target_col]

X_test = test_df[feature_cols]
y_test = test_df[target_col]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Normalize training data
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
import keras
from keras import layers
from keras.layers import Flatten
from keras.layers import Dense

def create_model():
  model = keras.Sequential([
      Dense(4, activation='tanh', input_shape=[len(feature_cols)]),
      Dense(6, activation='tanh'),
      Dense(1, activation='linear')
  ])

  model.compile(
      optimizer='adam',
      loss='mse',
      metrics=['mae', 'mse']
      )

  return model

model = create_model()

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │           368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 405 (1.58 KB)
#  Trainable params: 405 (1.58 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import os

checkpoint_path = "training_1/cp.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)
os.makedirs(checkpoint_dir, exist_ok=True)

cp_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    save_best_only=True,
    verbose=1
    )

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=7,
                                           restore_best_weights=True
                                           )

os.listdir(checkpoint_dir)

history = model.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    batch_size=256,
    validation_data=(X_val_scaled, y_val),
    callbacks=[cp_callback, early_stop]
    )
# Out:
# Epoch 1/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2744 - mae: 1.0944 - mse: 2.2744
# Epoch 1: val_loss improved from inf to 2.11227, saving model to training_1/cp.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 2.2742 - mae: 1.0940 - mse: 2.2742 - val_loss: 2.1123 - val_mae: 1.0071 - val_mse: 2.1123
# Epoch 2/100
# 47/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0469 - mae: 1.0138 - mse: 2.0469
# Epoch 2: val_loss improved from 2.11227 to 2.05648, saving model to training_1/cp.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0505 - mae: 1.0125 - mse: 2.0505 - val_loss: 2.0565 - val_mae: 0.9879 - val_mse: 2.0565
# Epoch 3/100
# 48/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1453 - mae: 1.0094 - mse: 2.1453
# Epoch 3: val_loss improved from 2.05648 to 2.04202, saving model to training_1/cp.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1211 - mae: 1.0056 - mse: 2.1211 - val_loss: 2.0420 - val_mae: 0.9824 - val_mse: 2.0420
# Epoch 4/100
# 47/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0031 - mae: 0.9817 - mse: 2.0031
# Epoch 4: val_loss improved from 2.04202 to 2.03387, saving model to training_1/cp.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0008 - mae: 0.9814 - mse: 2.0008 - val_loss: 2.0339 - val_mae: 0.9806 - val_mse: 2.0339
# Epoch 5/100
# 43/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0712 - mae: 0.9961 - mse: 2.0712
# Epoch 5: val_loss improved from 2.03387 to 2.02949, saving model to training_1/cp.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0532 - mae: 0.9929 - mse: 2.0532 - val_loss: 2.0295 - val_mae: 0.9811 - val_mse: 2.0295
# Epoch 6/100
# 47/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9961 - mae: 0.9785 - mse: 1.9961
# Epoch 6: val_loss improved from 2.02949 to 2.02776, saving model to training_1/cp.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9923 - mae: 0.9779 - mse: 1.9923 - val_loss: 2.0278 - val_mae: 0.9807 - val_mse: 2.0278
# Epoch 7/100
# 47/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0284 - mae: 0.9842 - mse: 2.0284
# Epoch 7: val_loss improved from 2.02776 to 2.02749, saving model to training_1/cp.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0192 - mae: 0.9827 - mse: 2.0192 - val_loss: 2.0275 - val_mae: 0.9807 - val_mse: 2.0275
# Epoch 8/100
# 48/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9092 - mae: 0.9670 - mse: 1.9092
# Epoch 8: val_loss did not improve from 2.02749
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9210 - mae: 0.9680 - mse: 1.9210 - val_loss: 2.0303 - val_mae: 0.9801 - val_mse: 2.0303
# Epoch 9/100
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9762 - mae: 0.9709 - mse: 1.9762
# Epoch 9: val_loss did not improve from 2.02749
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9760 - mae: 0.9711 - mse: 1.9760 - val_loss: 2.0293 - val_mae: 0.9810 - val_mse: 2.0293
# Epoch 10/100
# 51/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9479 - mae: 0.9692 - mse: 1.9479
# Epoch 10: val_loss did not improve from 2.02749
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9491 - mae: 0.9697 - mse: 1.9491 - val_loss: 2.0293 - val_mae: 0.9822 - val_mse: 2.0293
# Epoch 11/100
# 49/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9384 - mae: 0.9720 - mse: 1.9384
# Epoch 11: val_loss did not improve from 2.02749
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9400 - mae: 0.9720 - mse: 1.9400 - val_loss: 2.0337 - val_mae: 0.9818 - val_mse: 2.0337
# Epoch 12/100
# 46/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9022 - mae: 0.9551 - mse: 1.9022
# Epoch 12: val_loss did not improve from 2.02749
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.9153 - mae: 0.9586 - mse: 1.9153 - val_loss: 2.0300 - val_mae: 0.9832 - val_mse: 2.0300
# Epoch 13/100
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9956 - mae: 0.9793 - mse: 1.9956
# Epoch 13: val_loss did not improve from 2.02749
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9942 - mae: 0.9791 - mse: 1.9942 - val_loss: 2.0354 - val_mae: 0.9817 - val_mse: 2.0354
# Epoch 14/100
# 39/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0272 - mae: 0.9762 - mse: 2.0272
# Epoch 14: val_loss did not improve from 2.02749
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0066 - mae: 0.9748 - mse: 2.0066 - val_loss: 2.0349 - val_mae: 0.9846 - val_mse: 2.0349

# %%
history_dict = history.history
print(history_dict.keys())
# Out:
# dict_keys(['loss', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse'])

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'r--', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.xticks(epochs)
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import numpy as np

# Pick a random subset of validation data for permutation importance
rng = np.random.default_rng(42)
n_samples = min(10000, X_val_scaled.shape[0])

indices = rng.choice(X_val_scaled.shape[0], size=n_samples, replace=False)

X_val_sub = X_val_scaled[indices]
y_val_sub = y_val.iloc[indices] if hasattr(y_val, "iloc") else y_val[indices]

# %%
# define MAE scoring function for permutation importance
from sklearn.metrics import mean_absolute_error

def mae_scorer(model, X, y):
  y_pred = model.predict(X, batch_size=4096, verbose=0)
  return -mean_absolute_error(y, y_pred)  # negative because higher is better

mae_scorer(model, X_val_scaled, y_val)
# Out:
# -0.98072061300554

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(
    model,
    X_val_sub,
    y_val_sub,
    scoring=mae_scorer,
    n_repeats=5,
    random_state=42,
    n_jobs=1
    )

importance_df = pd.DataFrame({
    "feature": feature_cols,
    "importance": result.importances_mean
    })

importance_df.sort_values(by="importance", ascending=False, inplace=True)

top_k = 20
plt.figure(figsize=(8,6))
plt.barh(importance_df["feature"].head(top_k)[::-1],
         importance_df["importance"].head(top_k)[::-1])
plt.xlabel("Mean drop in validation score")
plt.title("Permutation feature importance")
# plt.tight_layout()
plt.show()

# %%
results = model.evaluate(X_test_scaled, y_test, batch_size=256)
print("test loss, test acc:", results)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.2361 - mae: 1.0069 - mse: 2.2361
# test loss, test acc: [2.174711227416992, 0.9911742806434631, 2.174711227416992]

# %%
# Obtain EPA predictions per play
y_pred = model.predict(X_test_scaled)
# Out:
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Add predictions back into test dataframe
test_df = test_df.copy()
test_df['EPA_pred'] = y_pred
test_df['EPA_true'] = y_test

# %%
# Aggregate per game
game_results = test_df.groupby("GameID")[["EPA_true", "EPA_pred"]].sum()
# Mean absolute EPA error per game
game_results["game_MAE"] = (game_results["EPA_true"] - game_results["EPA_pred"]).abs()
overall_game_MAE = game_results["game_MAE"].mean()
print(f"Overall game MAE: {overall_game_MAE}")
# Out:
# Overall game MAE: 25.91284492704194
